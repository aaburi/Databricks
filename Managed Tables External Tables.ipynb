# %%
df = spark.read.csv("/Volumes/demo/sample_data/samples/customer.csv", header=True, inferSchema=True)
#display(df) for a better view 
#df.show()
df.write.mode("overwrite").saveAsTable("demo.sample_data.customer_managed")

# %%
# This is for managed table class.
display(spark.sql("describe extended demo.sample_data.customer"))
